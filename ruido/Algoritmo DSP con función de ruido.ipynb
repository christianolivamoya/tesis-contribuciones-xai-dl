# %% [markdown]
# # Algoritmo DSP

# %% [markdown]
# En este notebook se encuentra el algoritmo original DSP aplicado sobre una red neuronal recurrente entrenada con la función de ruido. Está todo el código disponible para modificar exclusivamente los hiperparámetros del modelo y el dataset que se quiere utilizar.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tqdm import tqdm
from graphviz import Digraph

from sklearn.decomposition import PCA

# %% [markdown]
# ## Funciones auxiliares

# %%
# Función utilizada para preparar el dataset a un batch size con un seq_len determinado.
# Esta función se encarga de preparar el dataset de forma correcta para poder entrenar
# una red stateful por batches

def transform_many_to_many(input_file, output_file, batch_size, seq_len):
    input_raw = open(input_file, 'r').read()
    output_raw = open(output_file, 'r').read()
    
    symbol2id = {}
    id2symbol = {}
    for i, symbol in enumerate(["a", "b", "$"]):
        symbol2id[symbol] = i
        id2symbol[i] = symbol
    
    inputs_raw = []
    outputs_raw = []
    window_size = len(input_raw)//batch_size
    min_len = window_size+1
    for i in range(batch_size):
        string = input_raw[i*window_size:(i+1)*window_size]        
        output = output_raw[i*window_size:(i+1)*window_size]
        output = output[string.find("$"):]
        string = string[string.find("$"):]
        if len(string) < min_len:
            min_len = len(string)
        inputs_raw.append(string)
        outputs_raw.append(output)
        
    dataset_x_temp = np.zeros((batch_size, min_len))
    dataset_y_temp = np.zeros((batch_size, min_len))
    for i in range(batch_size):
        x = [symbol2id[s] for s in inputs_raw[i][:min_len]]
        y = [int(s) for s in outputs_raw[i][:min_len]]
        dataset_x_temp[i] = x
        dataset_y_temp[i] = y
    
    # Aqui, todas las cadenas empiezan por $ y todas tienen la misma longitud
    # OK
    # Ahora, es necesario recolocar las cadenas por lotes para stateful=True
    num_ventanas = min_len//seq_len
    dataset_x = np.zeros((batch_size*num_ventanas, seq_len))
    dataset_y = np.zeros((batch_size*num_ventanas, seq_len))
    for i in range(num_ventanas):
        lote_x = dataset_x_temp[:, i*seq_len:(i+1)*seq_len]
        lote_y = dataset_y_temp[:, i*seq_len:(i+1)*seq_len]
        dataset_x[i*batch_size:(i+1)*batch_size] = lote_x
        dataset_y[i*batch_size:(i+1)*batch_size] = lote_y
    return dataset_x[:, :, None] == np.arange(3)[None, None, :], dataset_y

# %%
# Función utilizada para preparar el dataset a un batch size = 1 con un seq_len determinado.
# Esta función hace lo mismo que la anterior pero asumiendo que el batch_size = 1 para poder
# evaluar después del entrenamiento

def transform_many_to_many_1b(input_file, output_file, batch_size):
    input_raw = open(input_file, 'r').read()
    output_raw = open(output_file, 'r').read()
    
    symbol2id = {}
    id2symbol = {}
    for i, symbol in enumerate(["a", "b", "$"]):
        symbol2id[symbol] = i
        id2symbol[i] = symbol
    
    inputs_raw = []
    outputs_raw = []
    window_size = len(input_raw)//batch_size
    min_len = window_size+1
    for i in range(batch_size):
        string = input_raw[i*window_size:(i+1)*window_size]        
        output = output_raw[i*window_size:(i+1)*window_size]
        output = output[string.find("$"):]
        string = string[string.find("$"):]
        if len(string) < min_len:
            min_len = len(string)
        inputs_raw.append(string)
        outputs_raw.append(output)
        
    dataset_x_temp = np.zeros((batch_size, min_len))
    dataset_y_temp = np.zeros((batch_size, min_len))
    for i in range(batch_size):
        x = [symbol2id[s] for s in inputs_raw[i][:min_len]]
        y = [int(s) for s in outputs_raw[i][:min_len]]
        dataset_x_temp[i] = x
        dataset_y_temp[i] = y
        
    return dataset_x_temp[:, :, None] == np.arange(3)[None, None, :], dataset_y_temp

# %%
# Esta función dibuja el autómata a partir de un conjunto de estados, transiciones, estados
# de aceptación y el estado inicial

def crear_diagrama_de_estados(estados, transiciones, aceptacion, estado_inicial, draw_dollar=True):
    # Crear un objeto Digraph
    fsm = Digraph(format='png')
    
    # Configurar orientación hacia la derecha
    fsm.attr(rankdir='LR')
    
    fsm.node("", shape="none", label="")  # Nodo invisible para la flecha inicial
    fsm.edge("", str(estado_inicial))  # Flecha hacia el estado inicial

    # Añadir los estados (nodos)
    for estado in estados:
        if str(estado) == "-2":
            continue
        if estado in aceptacion:
            if True in aceptacion[estado] and False in aceptacion[estado]:
                if aceptacion[estado][True] > aceptacion[estado][False]:
                    fsm.node(str(estado), shape="doublecircle")
                else:
                    fsm.node(str(estado))
            elif True in aceptacion[estado]:
                fsm.node(str(estado), shape="doublecircle")
            else:
                fsm.node(str(estado))
        else:
            fsm.node(str(estado))

    # Añadir las transiciones (aristas)
    for origen in transiciones:
        if str(origen) == "-2":
            continue
        for simbolo in transiciones[origen]:
            if not draw_dollar and simbolo == "$":
                continue
            for destino in transiciones[origen][simbolo]:
                if str(destino) == "-2":
                    continue
                fsm.edge(str(origen), str(destino), label=simbolo)

    # Mostrar el grafo
    return fsm

# %%
# Este bloque de código tiene las funciones necesarias para pasar a determinista y minimizar un autómata

def _join_states(states, estado_aceptacion):
        state_names = [str(s) for s in states] # Copia
        state_names.sort()
        new_name = "+".join(state_names)
        return new_name, any(True in estado_aceptacion[s] for s in states)
    
def _process_symbol(current_states, symbol, tabla_transiciones):
    new_current_states = []
    for state in current_states:
        if state in tabla_transiciones:
            if symbol in tabla_transiciones[state]:
                for end_state in tabla_transiciones[state][symbol]:
                    new_current_states.append(end_state)
    return list(set(new_current_states))

def to_deterministic(tabla_transiciones, estado_aceptacion, initial_state=-1):
    """
        Esta función construye un Autómata Finito Determinista a partir del
          automata original.

        Args: No args

        Return:
            Un autómata finito determinista
    """
    # Initial state
    dfa_initial_state = str(initial_state)
    dfa_states = {dfa_initial_state}
    dfa_symbols = ["a", "b", "$"]
    dfa_transitions = {}
    dfa_estado_aceptacion = {dfa_initial_state: {True in estado_aceptacion[initial_state]: 1.0}}

    q = []
    q.append((dfa_initial_state, [initial_state]))
    while q:
        joint_state, current_states = q[0]
        q = q[1:]
        for s in dfa_symbols:
            current_states = current_states
            new_current_states = _process_symbol(current_states, s, tabla_transiciones)

            new_joint_state, new_aceptacion = _join_states(new_current_states, estado_aceptacion)
            if not new_joint_state in dfa_states:
                dfa_states.add(new_joint_state)
                dfa_estado_aceptacion[new_joint_state] = {new_aceptacion: 1.0}
                q.append((new_joint_state, new_current_states))

            if joint_state in dfa_transitions:
                if s in dfa_transitions:
                    dfa_transitions[joint_state][s][new_joint_state] = 1.0
                else:
                    dfa_transitions[joint_state][s] = {new_joint_state: 1.0}
            else:
                dfa_transitions[joint_state] = {s: {new_joint_state: 1.0}}
                
            

    return dfa_initial_state, dfa_states, dfa_transitions, dfa_estado_aceptacion

def _get_reachable_states(tabla_transiciones, estado_ini):
    pending = []
    pending.append(estado_ini)
    reachable_states = []

    while pending:
        state = pending[0]
        pending = pending[1:]
        if state not in reachable_states:
            reachable_states.append(state)
            for symbol in tabla_transiciones[state]:
                end_state = list(tabla_transiciones[state][symbol].keys())[0]
                pending.append(end_state)
    return reachable_states

def _assign_eq_classes(old_eq_classes, reachable_states, tabla_transiciones):
    def _state_same_transitions(s1, s2):
        for symbol in ["a", "b", "$"]:
            eq_class1 = []
            eq_class2 = []
            for end_state in tabla_transiciones[s1][symbol]:
                eq_class1.append(old_eq_classes[end_state])
            for end_state in tabla_transiciones[s2][symbol]:
                eq_class2.append(old_eq_classes[end_state])

            if eq_class1 != eq_class2:
                return False
        return True

    current_eq_classes = {s: -1 for s in reachable_states}
    next_eq_class = 0
    states = list(current_eq_classes.keys())
    for i, state in enumerate(states):
        if current_eq_classes[state] == -1:
            current_eq_classes[state] = next_eq_class

            for j in range(i, len(states)):
                if (current_eq_classes[states[j]] == -1 and
                    old_eq_classes[state] == old_eq_classes[states[j]] and
                    _state_same_transitions(state, states[j])):
                        current_eq_classes[states[j]] = next_eq_class
            next_eq_class += 1
    return current_eq_classes, next_eq_class

def minimize(estados, tabla_transiciones, estado_aceptacion, estado_ini):
        """
            Esta función minimiza un Autómata Finito Determinista"

            Args: No args

            Return:
                Un autómata finito determinista mínimo
        """

        reachable_states = _get_reachable_states(tabla_transiciones, estado_ini)
        old_eq_classes = {s: -1 for s in reachable_states}
        current_eq_classes = {}
        for s in reachable_states:
            current_eq_classes[s] = 1 if s in estado_aceptacion and True in estado_aceptacion[s] else 0

        while current_eq_classes != old_eq_classes:
            old_eq_classes = current_eq_classes
            current_eq_classes, n_classes = _assign_eq_classes(old_eq_classes, reachable_states, tabla_transiciones)

        nuevos_estados = []        
        nuevo_estado_aceptacion = {}
        nueva_tabla_transiciones = {}

        for state, value in current_eq_classes.items():
            new_state = str(value)
            new_state_aceptacion = estado_aceptacion[state]
            if new_state not in nuevos_estados:
                nuevos_estados.append(new_state)
                nuevo_estado_aceptacion[new_state] = new_state_aceptacion


        for state_old, value in current_eq_classes.items():
            start_state = nuevos_estados[value]
            for symbol in ["a", "b", "$"]:
                end_state = list(tabla_transiciones[state_old][symbol].keys())[0]

                end_state = nuevos_estados[current_eq_classes[end_state]]
                if start_state in nueva_tabla_transiciones:
                    if symbol not in nueva_tabla_transiciones[start_state]:
                        nueva_tabla_transiciones[start_state][symbol] = {end_state: 1.0}
                else:
                    nueva_tabla_transiciones[start_state] = {symbol: {end_state: 1.0}}

        return nuevos_estados, nueva_tabla_transiciones, nuevo_estado_aceptacion, current_eq_classes[estado_ini], current_eq_classes

# %%
# Función de activación con ruido
def noisy_tanh(noise_level=0.0):
    @tf.function()
    def _noisy_tanh(x):
        output = tf.tanh(x * tf.random.normal(x.shape, mean=1.0, stddev=noise_level))
        return output
    return _noisy_tanh

# %%
# Función de construcción del modelo

def build_model(units, batch_size=1, input_dim=3, l1reg=0.0, noise_level=0.0, optimizer="Adam", use_stateful=True):
    if not use_stateful:
        input_layer = tf.keras.Input(batch_shape=(1, None, input_dim))
        stateful = False
    else:
        input_layer = tf.keras.Input(batch_shape=(batch_size, None, input_dim))
        stateful = True
    rec_layer = tf.keras.layers.SimpleRNN(units, return_sequences=True, 
                                          stateful=stateful,
                                          activation=noisy_tanh(noise_level),
                                          kernel_regularizer=tf.keras.regularizers.l1(l1reg),
                                          recurrent_regularizer=tf.keras.regularizers.l1(l1reg),
                                          kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                          recurrent_initializer=tf.keras.initializers.RandomNormal(stddev=0.01)
                                         )(input_layer)
    output_layer = tf.keras.layers.Dense(2, activation="softmax",
                                         kernel_regularizer=tf.keras.regularizers.l1(l1reg),
                                         kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01)
                                        )(rec_layer)
    
    model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=optimizer, loss=tf.keras.losses.SparseCategoricalCrossentropy(reduction="sum"), metrics=["accuracy"])
    
    model_rec = tf.keras.Model(inputs=input_layer, outputs=rec_layer)
    return model, model_rec

# %% [markdown]
# ## Descarga de datos

# %% [markdown]
# Se descargan los datos de Github directamente.

# %%
seq_len = 25
batch_size = 20

path = "https://raw.githubusercontent.com/christianolivamoya/tesis-contribuciones-xai-dl/refs/heads/main/dataset/tomita/"
problema = "paridad"

input_file = problema + "_train_x.txt"
output_file = problema + "_train_y.txt"
try:
    dataset_x_train, dataset_y_train = transform_many_to_many(input_file, output_file, batch_size, seq_len)
except:
    # !wget $path"train/"$input_file
    # !wget $path"train/"$output_file
    dataset_x_train, dataset_y_train = transform_many_to_many(input_file, output_file, batch_size, seq_len)
print(dataset_x_train.shape, dataset_y_train.shape)
dataset_x_train_b1, dataset_y_train_b1 = transform_many_to_many_1b(input_file, output_file, 1)
print(dataset_x_train_b1.shape, dataset_y_train_b1.shape)

input_file = problema + "_cadenasLargas_x.txt"
output_file = problema + "_cadenasLargas_y.txt"
try:
    dataset_x_long, dataset_y_long = transform_many_to_many_1b(input_file, output_file, 1)
except:
    # !wget $path"test/"$input_file
    # !wget $path"test/"$output_file
    dataset_x_long, dataset_y_long = transform_many_to_many_1b(input_file, output_file, 1)
print (dataset_x_long.shape, dataset_y_long.shape)

input_file = problema + "_extremo_muchasA_x.txt"
output_file = problema + "_extremo_muchasA_y.txt"
try:
    dataset_x_allas, dataset_y_allas = transform_many_to_many_1b(input_file, output_file, 1)
except:
    # !wget $path"test/"$input_file
    # !wget $path"test/"$output_file
    dataset_x_allas, dataset_y_allas = transform_many_to_many_1b(input_file, output_file, 1)
print (dataset_x_allas.shape, dataset_y_allas.shape)

input_file = problema + "_extremo_muchasB_x.txt"
output_file = problema + "_extremo_muchasB_y.txt"
try:
    dataset_x_allbs, dataset_y_allbs = transform_many_to_many_1b(input_file, output_file, 1)
except:
    # !wget $path"test/"$input_file
    # !wget $path"test/"$output_file
    dataset_x_allbs, dataset_y_allbs = transform_many_to_many_1b(input_file, output_file, 1)
print (dataset_x_allbs.shape, dataset_y_allbs.shape)

input_file = problema + "_testGrande_x.txt"
output_file = problema + "_testGrande_y.txt"
try:
    dataset_x_big, dataset_y_big = transform_many_to_many_1b(input_file, output_file, 1)
except:
    # !wget $path"test/"$input_file
    # !wget $path"test/"$output_file
    dataset_x_big, dataset_y_big = transform_many_to_many_1b(input_file, output_file, 1)
print (dataset_x_big.shape, dataset_y_big.shape)
# Out:
# (1940, 25, 3) (1940, 25)
# (1, 50001, 3) (1, 50001)
# (1, 20001, 3) (1, 20001)
# (1, 15001, 3) (1, 15001)
# (1, 15001, 3) (1, 15001)
# (1, 100001, 3) (1, 100001)

# %% [markdown]
# ## Entrenamiento del modelo

# %% [markdown]
# Encontrar un modelo apropiado que tenga las neuronas regularizadas o binarizadas completamente puede ser una tarea tediosa. Sin embargo, el entrenamiento siempre será correcto con un 100% en todos los tests.

# %%
with tf.device('/CPU:0'):
    hidden_size=10
    min_epochs=500
    l1reg=0.1
    noise_level=0.5
    learning_rate=0.005
    optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, clipvalue=5.0)
    model, model_rec = build_model(hidden_size, 
                                   batch_size, 
                                   optimizer=optimizer, 
                                   l1reg=l1reg, 
                                   noise_level=noise_level)
    model_temp, model_rec_temp = build_model(hidden_size, use_stateful=False)
    model.summary()
    
    epoch = 0
    while True:
        if epoch % 10 == 0:
            print(" > Epoch", epoch)
        model.reset_states()
        hist = model.fit(dataset_x_train, dataset_y_train, 
                         shuffle=False, batch_size=batch_size)
        if epoch >= min_epochs:
            model.save_weights("training")
            model_temp.load_weights("training")
            h = model_temp.evaluate(dataset_x_train_b1, dataset_y_train_b1, batch_size=1)
            if h[1] == 1.0:
                break
        epoch += 1
# Out:
# Model: "model_88"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_45 (InputLayer)       [(20, None, 3)]           0
#
#  simple_rnn_44 (SimpleRNN)   (20, None, 10)            140
#
#  dense_44 (Dense)            (20, None, 2)             22
#
# =================================================================
# Total params: 162 (648.00 Byte)
# Trainable params: 162 (648.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#  > Epoch 0
# 97/97 [==============================] - 1s 3ms/step - loss: 321.6367 - accuracy: 0.5738
# 97/97 [==============================] - 0s 3ms/step - loss: 314.2914 - accuracy: 0.5739
# 97/97 [==============================] - 0s 3ms/step - loss: 313.7511 - accuracy: 0.5706
# 97/97 [==============================] - 0s 3ms/step - loss: 308.8326 - accuracy: 0.5922
# 97/97 [==============================] - 0s 3ms/step - loss: 295.4857 - accuracy: 0.6357
# 97/97 [==============================] - 0s 3ms/step - loss: 264.2301 - accuracy: 0.7144
# 97/97 [==============================] - 0s 3ms/step - loss: 208.6095 - accuracy: 0.8289
# 97/97 [==============================] - 0s 3ms/step - loss: 133.9672 - accuracy: 0.9201
# 97/97 [==============================] - 0s 3ms/step - loss: 88.1197 - accuracy: 0.9575
# 97/97 [==============================] - 0s 3ms/step - loss: 63.4949 - accuracy: 0.9738
#  > Epoch 10
# 97/97 [==============================] - 0s 3ms/step - loss: 60.8749 - accuracy: 0.9759
# 97/97 [==============================] - 0s 3ms/step - loss: 39.7440 - accuracy: 0.9868
# 97/97 [==============================] - 0s 3ms/step - loss: 46.9776 - accuracy: 0.9844
# 97/97 [==============================] - 0s 3ms/step - loss: 43.2975 - accuracy: 0.9864
# 97/97 [==============================] - 0s 3ms/step - loss: 35.6983 - accuracy: 0.9899
# 97/97 [==============================] - 0s 3ms/step - loss: 32.7442 - accuracy: 0.9921
# 97/97 [==============================] - 0s 4ms/step - loss: 27.2808 - accuracy: 0.9937
# 97/97 [==============================] - 0s 3ms/step - loss: 29.7345 - accuracy: 0.9923
# 97/97 [==============================] - 0s 3ms/step - loss: 28.5777 - accuracy: 0.9934
# 97/97 [==============================] - 0s 3ms/step - loss: 20.0237 - accuracy: 0.9967
#  > Epoch 20
# 97/97 [==============================] - 0s 3ms/step - loss: 38.4817 - accuracy: 0.9894
# 97/97 [==============================] - 0s 3ms/step - loss: 23.1062 - accuracy: 0.9955
# 97/97 [==============================] - 0s 4ms/step - loss: 34.5014 - accuracy: 0.9913
# 97/97 [==============================] - 0s 3ms/step - loss: 31.8544 - accuracy: 0.9919
# 97/97 [==============================] - 0s 3ms/step - loss: 35.3573 - accuracy: 0.9910
# 97/97 [==============================] - 0s 3ms/step - loss: 23.8237 - accuracy: 0.9958
# 97/97 [==============================] - 0s 3ms/step - loss: 29.5783 - accuracy: 0.9934
# 97/97 [==============================] - 0s 3ms/step - loss: 30.7113 - accuracy: 0.9930
# 97/97 [==============================] - 0s 3ms/step - loss: 33.6962 - accuracy: 0.9910
# 97/97 [==============================] - 0s 3ms/step - loss: 21.9613 - accuracy: 0.9962
#  > Epoch 30
# 97/97 [==============================] - 0s 3ms/step - loss: 28.8965 - accuracy: 0.9933
# 97/97 [==============================] - 0s 3ms/step - loss: 20.5636 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 28.4112 - accuracy: 0.9939
# 97/97 [==============================] - 0s 3ms/step - loss: 22.5601 - accuracy: 0.9958
# 97/97 [==============================] - 0s 3ms/step - loss: 23.8350 - accuracy: 0.9954
# 97/97 [==============================] - 0s 3ms/step - loss: 21.4674 - accuracy: 0.9963
# 97/97 [==============================] - 0s 3ms/step - loss: 29.7738 - accuracy: 0.9938
# 97/97 [==============================] - 0s 3ms/step - loss: 22.9599 - accuracy: 0.9957
# 97/97 [==============================] - 0s 3ms/step - loss: 20.6383 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 22.6123 - accuracy: 0.9958
#  > Epoch 40
# 97/97 [==============================] - 0s 3ms/step - loss: 20.7122 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 26.2329 - accuracy: 0.9946
# 97/97 [==============================] - 0s 3ms/step - loss: 22.1743 - accuracy: 0.9962
# 97/97 [==============================] - 0s 3ms/step - loss: 24.5587 - accuracy: 0.9953
# 97/97 [==============================] - 0s 3ms/step - loss: 23.7282 - accuracy: 0.9958
# 97/97 [==============================] - 0s 3ms/step - loss: 21.5427 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 20.0671 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 25.8220 - accuracy: 0.9945
# 97/97 [==============================] - 0s 3ms/step - loss: 26.2937 - accuracy: 0.9943
# 97/97 [==============================] - 0s 3ms/step - loss: 20.5647 - accuracy: 0.9964
#  > Epoch 50
# 97/97 [==============================] - 0s 3ms/step - loss: 23.0630 - accuracy: 0.9958
# 97/97 [==============================] - 0s 3ms/step - loss: 21.1742 - accuracy: 0.9961
# 97/97 [==============================] - 0s 3ms/step - loss: 24.8799 - accuracy: 0.9947
# 97/97 [==============================] - 0s 3ms/step - loss: 23.0283 - accuracy: 0.9957
# 97/97 [==============================] - 0s 3ms/step - loss: 15.8164 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 17.6553 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 24.5038 - accuracy: 0.9951
# 97/97 [==============================] - 0s 3ms/step - loss: 29.1163 - accuracy: 0.9939
# 97/97 [==============================] - 0s 3ms/step - loss: 28.3412 - accuracy: 0.9938
# 97/97 [==============================] - 0s 3ms/step - loss: 21.2037 - accuracy: 0.9964
#  > Epoch 60
# 97/97 [==============================] - 0s 3ms/step - loss: 25.6445 - accuracy: 0.9952
# 97/97 [==============================] - 0s 3ms/step - loss: 20.2777 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 15.6913 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5141 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5316 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6270 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 16.3889 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 20.1614 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 21.4034 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 25.0777 - accuracy: 0.9949
#  > Epoch 70
# 97/97 [==============================] - 0s 3ms/step - loss: 23.2362 - accuracy: 0.9959
# 97/97 [==============================] - 0s 3ms/step - loss: 14.0199 - accuracy: 0.9990
# 97/97 [==============================] - 0s 3ms/step - loss: 14.4804 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 20.8982 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 21.6328 - accuracy: 0.9963
# 97/97 [==============================] - 0s 3ms/step - loss: 14.0716 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 20.8137 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 14.1041 - accuracy: 0.9989
# 97/97 [==============================] - 0s 3ms/step - loss: 18.2262 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 14.2960 - accuracy: 0.9989
#  > Epoch 80
# 97/97 [==============================] - 0s 3ms/step - loss: 14.9181 - accuracy: 0.9986
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6759 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 21.8804 - accuracy: 0.9963
# 97/97 [==============================] - 0s 3ms/step - loss: 22.1410 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 13.4031 - accuracy: 0.9991
# 97/97 [==============================] - 0s 3ms/step - loss: 23.3708 - accuracy: 0.9961
# 97/97 [==============================] - 0s 3ms/step - loss: 24.1000 - accuracy: 0.9956
# 97/97 [==============================] - 0s 3ms/step - loss: 17.7166 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 24.7842 - accuracy: 0.9952
# 97/97 [==============================] - 0s 3ms/step - loss: 22.9999 - accuracy: 0.9964
#  > Epoch 90
# 97/97 [==============================] - 0s 3ms/step - loss: 17.7715 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 17.9992 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 16.5937 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 22.3477 - accuracy: 0.9966
# 97/97 [==============================] - 0s 3ms/step - loss: 26.8290 - accuracy: 0.9948
# 97/97 [==============================] - 0s 3ms/step - loss: 15.4094 - accuracy: 0.9986
# 66/97 [===================>..........] - ETA: 0s - loss: 17.2820 - accuracy: 0.9976WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# 97/97 [==============================] - 1s 6ms/step - loss: 16.5888 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 15.0811 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 18.3656 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 22.0692 - accuracy: 0.9961
#  > Epoch 100
# 97/97 [==============================] - 0s 3ms/step - loss: 13.1535 - accuracy: 0.9994
# 97/97 [==============================] - 0s 3ms/step - loss: 19.1703 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 13.8380 - accuracy: 0.9993
# 97/97 [==============================] - 0s 3ms/step - loss: 20.7779 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 21.3388 - accuracy: 0.9962
# 97/97 [==============================] - 0s 3ms/step - loss: 17.8275 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 15.1618 - accuracy: 0.9983
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5365 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5014 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 19.2125 - accuracy: 0.9972
#  > Epoch 110
# 97/97 [==============================] - 0s 3ms/step - loss: 20.9799 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 18.2199 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 24.7616 - accuracy: 0.9953
# 97/97 [==============================] - 0s 3ms/step - loss: 18.6634 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 14.5946 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5223 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 21.7528 - accuracy: 0.9961
# 97/97 [==============================] - 0s 3ms/step - loss: 16.4163 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 21.6499 - accuracy: 0.9968
# 97/97 [==============================] - 0s 3ms/step - loss: 15.8287 - accuracy: 0.9984
#  > Epoch 120
# 97/97 [==============================] - 0s 3ms/step - loss: 24.2451 - accuracy: 0.9958
# 97/97 [==============================] - 0s 3ms/step - loss: 22.4127 - accuracy: 0.9962
# 97/97 [==============================] - 0s 3ms/step - loss: 13.3640 - accuracy: 0.9992
# 97/97 [==============================] - 0s 3ms/step - loss: 15.2124 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 24.5337 - accuracy: 0.9951
# 97/97 [==============================] - 0s 3ms/step - loss: 15.2669 - accuracy: 0.9983
# 97/97 [==============================] - 0s 3ms/step - loss: 15.4640 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 16.9180 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 16.1544 - accuracy: 0.9980
# 97/97 [==============================] - 0s 4ms/step - loss: 18.8402 - accuracy: 0.9973
#  > Epoch 130
# 97/97 [==============================] - 0s 4ms/step - loss: 21.6338 - accuracy: 0.9964
# 97/97 [==============================] - 0s 4ms/step - loss: 15.6950 - accuracy: 0.9982
# 97/97 [==============================] - 0s 4ms/step - loss: 20.8887 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 21.6061 - accuracy: 0.9963
# 97/97 [==============================] - 0s 3ms/step - loss: 14.4702 - accuracy: 0.9989
# 97/97 [==============================] - 0s 4ms/step - loss: 14.0733 - accuracy: 0.9990
# 97/97 [==============================] - 0s 4ms/step - loss: 16.5110 - accuracy: 0.9981
# 97/97 [==============================] - 0s 4ms/step - loss: 14.3779 - accuracy: 0.9986
# 97/97 [==============================] - 0s 4ms/step - loss: 15.1441 - accuracy: 0.9983
# 97/97 [==============================] - 0s 4ms/step - loss: 17.7117 - accuracy: 0.9977
#  > Epoch 140
# 97/97 [==============================] - 0s 3ms/step - loss: 15.1627 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 21.4210 - accuracy: 0.9961
# 97/97 [==============================] - 0s 3ms/step - loss: 15.8451 - accuracy: 0.9986
# 97/97 [==============================] - 0s 3ms/step - loss: 13.6178 - accuracy: 0.9991
# 97/97 [==============================] - 0s 3ms/step - loss: 17.4647 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 24.3504 - accuracy: 0.9951
# 97/97 [==============================] - 0s 3ms/step - loss: 22.9648 - accuracy: 0.9960
# 97/97 [==============================] - 0s 3ms/step - loss: 16.3388 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 21.2537 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 18.7551 - accuracy: 0.9971
#  > Epoch 150
# 97/97 [==============================] - 0s 3ms/step - loss: 15.3222 - accuracy: 0.9983
# 97/97 [==============================] - 0s 3ms/step - loss: 19.5226 - accuracy: 0.9971
# 97/97 [==============================] - 0s 3ms/step - loss: 20.4145 - accuracy: 0.9966
# 97/97 [==============================] - 0s 3ms/step - loss: 23.3011 - accuracy: 0.9955
# 97/97 [==============================] - 0s 3ms/step - loss: 19.6868 - accuracy: 0.9971
# 97/97 [==============================] - 0s 3ms/step - loss: 13.8914 - accuracy: 0.9989
# 97/97 [==============================] - 0s 3ms/step - loss: 17.7097 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 22.7343 - accuracy: 0.9955
# 97/97 [==============================] - 0s 3ms/step - loss: 18.3937 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 18.3176 - accuracy: 0.9975
#  > Epoch 160
# 97/97 [==============================] - 0s 3ms/step - loss: 16.7992 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 15.6199 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6661 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 17.1665 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 26.6191 - accuracy: 0.9944
# 97/97 [==============================] - 0s 3ms/step - loss: 13.7499 - accuracy: 0.9989
# 97/97 [==============================] - 0s 3ms/step - loss: 19.8900 - accuracy: 0.9971
# 97/97 [==============================] - 0s 3ms/step - loss: 18.7291 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6784 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 19.1818 - accuracy: 0.9970
#  > Epoch 170
# 97/97 [==============================] - 0s 3ms/step - loss: 20.3789 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 18.1639 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 21.0412 - accuracy: 0.9962
# 97/97 [==============================] - 0s 3ms/step - loss: 14.3639 - accuracy: 0.9987
# 97/97 [==============================] - 0s 4ms/step - loss: 15.2518 - accuracy: 0.9982
# 97/97 [==============================] - 0s 4ms/step - loss: 23.3158 - accuracy: 0.9957
# 97/97 [==============================] - 0s 3ms/step - loss: 17.4403 - accuracy: 0.9980
# 97/97 [==============================] - 0s 4ms/step - loss: 16.2472 - accuracy: 0.9983
# 97/97 [==============================] - 0s 4ms/step - loss: 20.4318 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 18.6462 - accuracy: 0.9975
#  > Epoch 180
# 97/97 [==============================] - 0s 3ms/step - loss: 20.1037 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 14.7090 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 21.0977 - accuracy: 0.9966
# 97/97 [==============================] - 0s 4ms/step - loss: 19.8799 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 14.1883 - accuracy: 0.9986
# 97/97 [==============================] - 0s 3ms/step - loss: 16.9441 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 19.4075 - accuracy: 0.9972
# 97/97 [==============================] - 0s 4ms/step - loss: 17.0705 - accuracy: 0.9980
# 97/97 [==============================] - 0s 4ms/step - loss: 17.7395 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 19.2384 - accuracy: 0.9968
#  > Epoch 190
# 97/97 [==============================] - 0s 4ms/step - loss: 19.7528 - accuracy: 0.9969
# 97/97 [==============================] - 0s 4ms/step - loss: 17.5168 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 22.6183 - accuracy: 0.9962
# 97/97 [==============================] - 0s 4ms/step - loss: 17.8636 - accuracy: 0.9976
# 97/97 [==============================] - 0s 4ms/step - loss: 19.6335 - accuracy: 0.9968
# 97/97 [==============================] - 0s 4ms/step - loss: 18.0413 - accuracy: 0.9975
# 97/97 [==============================] - 0s 4ms/step - loss: 18.6732 - accuracy: 0.9975
# 97/97 [==============================] - 0s 4ms/step - loss: 23.3935 - accuracy: 0.9958
# 97/97 [==============================] - 0s 4ms/step - loss: 18.1584 - accuracy: 0.9975
# 97/97 [==============================] - 0s 4ms/step - loss: 19.5255 - accuracy: 0.9972
#  > Epoch 200
# 97/97 [==============================] - 0s 4ms/step - loss: 18.0046 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 19.3445 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 20.4175 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 13.0635 - accuracy: 0.9991
# 97/97 [==============================] - 0s 3ms/step - loss: 23.2236 - accuracy: 0.9958
# 97/97 [==============================] - 0s 3ms/step - loss: 19.1332 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6052 - accuracy: 0.9986
# 97/97 [==============================] - 0s 3ms/step - loss: 18.9266 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5789 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 18.4094 - accuracy: 0.9974
#  > Epoch 210
# 97/97 [==============================] - 0s 3ms/step - loss: 25.7368 - accuracy: 0.9950
# 97/97 [==============================] - 0s 3ms/step - loss: 18.9590 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 20.3913 - accuracy: 0.9966
# 97/97 [==============================] - 0s 3ms/step - loss: 18.2516 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 14.8716 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6339 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 23.8615 - accuracy: 0.9957
# 97/97 [==============================] - 0s 3ms/step - loss: 20.4357 - accuracy: 0.9963
# 97/97 [==============================] - 0s 3ms/step - loss: 16.4301 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 14.5143 - accuracy: 0.9987
#  > Epoch 220
# 97/97 [==============================] - 0s 3ms/step - loss: 20.6830 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 14.8079 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 21.2445 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 22.9965 - accuracy: 0.9959
# 97/97 [==============================] - 0s 3ms/step - loss: 14.2265 - accuracy: 0.9989
# 97/97 [==============================] - 0s 3ms/step - loss: 19.4355 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 24.3365 - accuracy: 0.9955
# 97/97 [==============================] - 0s 3ms/step - loss: 20.9651 - accuracy: 0.9966
# 97/97 [==============================] - 0s 3ms/step - loss: 12.5154 - accuracy: 0.9994
# 97/97 [==============================] - 0s 3ms/step - loss: 18.7174 - accuracy: 0.9975
#  > Epoch 230
# 97/97 [==============================] - 0s 3ms/step - loss: 19.5032 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 20.4846 - accuracy: 0.9968
# 97/97 [==============================] - 0s 3ms/step - loss: 17.4657 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 19.4056 - accuracy: 0.9971
# 97/97 [==============================] - 0s 3ms/step - loss: 19.1238 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 17.4215 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 15.8828 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 20.7058 - accuracy: 0.9964
# 97/97 [==============================] - 0s 3ms/step - loss: 15.9467 - accuracy: 0.9983
# 97/97 [==============================] - 0s 3ms/step - loss: 21.5833 - accuracy: 0.9963
#  > Epoch 240
# 97/97 [==============================] - 0s 3ms/step - loss: 16.8695 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 14.5099 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 16.0259 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 17.9264 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 18.3590 - accuracy: 0.9968
# 97/97 [==============================] - 0s 3ms/step - loss: 16.4669 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 13.4168 - accuracy: 0.9992
# 97/97 [==============================] - 0s 3ms/step - loss: 16.3996 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 20.0253 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6207 - accuracy: 0.9989
#  > Epoch 250
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6221 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 19.9148 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 17.6719 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 15.2942 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 19.1562 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 18.2689 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 15.7123 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 19.0457 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 16.8637 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 16.5744 - accuracy: 0.9979
#  > Epoch 260
# 97/97 [==============================] - 0s 3ms/step - loss: 22.7171 - accuracy: 0.9956
# 97/97 [==============================] - 0s 3ms/step - loss: 20.1242 - accuracy: 0.9966
# 97/97 [==============================] - 0s 3ms/step - loss: 14.5846 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 16.2097 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 23.5999 - accuracy: 0.9954
# 97/97 [==============================] - 0s 3ms/step - loss: 15.8715 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 15.8284 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 14.8963 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 15.9082 - accuracy: 0.9983
# 97/97 [==============================] - 0s 4ms/step - loss: 20.3214 - accuracy: 0.9963
#  > Epoch 270
# 97/97 [==============================] - 0s 4ms/step - loss: 16.9146 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 24.3320 - accuracy: 0.9955
# 97/97 [==============================] - 0s 4ms/step - loss: 17.4125 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 21.6886 - accuracy: 0.9963
# 97/97 [==============================] - 0s 3ms/step - loss: 22.0217 - accuracy: 0.9961
# 97/97 [==============================] - 0s 3ms/step - loss: 17.2011 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 13.8332 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 15.4960 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 24.6282 - accuracy: 0.9947
# 97/97 [==============================] - 0s 4ms/step - loss: 17.3466 - accuracy: 0.9977
#  > Epoch 280
# 97/97 [==============================] - 0s 3ms/step - loss: 15.2262 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 16.4485 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6708 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 19.6781 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 19.6179 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 20.2068 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 23.5682 - accuracy: 0.9955
# 97/97 [==============================] - 0s 3ms/step - loss: 18.4513 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 17.2987 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 23.2534 - accuracy: 0.9958
#  > Epoch 290
# 97/97 [==============================] - 0s 3ms/step - loss: 16.2567 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 14.3676 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 18.2052 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 19.7920 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 16.0409 - accuracy: 0.9984
# 97/97 [==============================] - 0s 4ms/step - loss: 17.1577 - accuracy: 0.9978
# 97/97 [==============================] - 0s 4ms/step - loss: 16.6565 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6466 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 16.7316 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 18.1946 - accuracy: 0.9974
#  > Epoch 300
# 97/97 [==============================] - 0s 3ms/step - loss: 12.7865 - accuracy: 0.9993
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5313 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 20.3937 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 23.1649 - accuracy: 0.9957
# 97/97 [==============================] - 0s 3ms/step - loss: 18.3012 - accuracy: 0.9972
# 97/97 [==============================] - 0s 4ms/step - loss: 16.8704 - accuracy: 0.9981
# 97/97 [==============================] - 0s 4ms/step - loss: 16.1654 - accuracy: 0.9985
# 97/97 [==============================] - 0s 4ms/step - loss: 17.6787 - accuracy: 0.9975
# 97/97 [==============================] - 0s 4ms/step - loss: 15.2085 - accuracy: 0.9983
# 97/97 [==============================] - 0s 4ms/step - loss: 14.9152 - accuracy: 0.9985
#  > Epoch 310
# 97/97 [==============================] - 0s 4ms/step - loss: 23.4568 - accuracy: 0.9959
# 97/97 [==============================] - 0s 4ms/step - loss: 22.5331 - accuracy: 0.9962
# 97/97 [==============================] - 0s 4ms/step - loss: 13.9730 - accuracy: 0.9991
# 97/97 [==============================] - 0s 4ms/step - loss: 17.4283 - accuracy: 0.9976
# 97/97 [==============================] - 0s 4ms/step - loss: 15.8758 - accuracy: 0.9981
# 97/97 [==============================] - 0s 4ms/step - loss: 21.6323 - accuracy: 0.9961
# 97/97 [==============================] - 0s 4ms/step - loss: 24.8558 - accuracy: 0.9958
# 97/97 [==============================] - 0s 4ms/step - loss: 15.3521 - accuracy: 0.9983
# 97/97 [==============================] - 0s 4ms/step - loss: 15.1444 - accuracy: 0.9984
# 97/97 [==============================] - 0s 4ms/step - loss: 18.1607 - accuracy: 0.9975
#  > Epoch 320
# 97/97 [==============================] - 0s 4ms/step - loss: 21.7229 - accuracy: 0.9962
# 97/97 [==============================] - 0s 4ms/step - loss: 15.7254 - accuracy: 0.9982
# 97/97 [==============================] - 0s 4ms/step - loss: 25.8145 - accuracy: 0.9951
# 97/97 [==============================] - 0s 3ms/step - loss: 19.7158 - accuracy: 0.9971
# 97/97 [==============================] - 0s 4ms/step - loss: 20.3627 - accuracy: 0.9966
# 97/97 [==============================] - 0s 4ms/step - loss: 12.9897 - accuracy: 0.9993
# 97/97 [==============================] - 0s 3ms/step - loss: 21.1752 - accuracy: 0.9965
# 97/97 [==============================] - 0s 4ms/step - loss: 31.7934 - accuracy: 0.9925
# 97/97 [==============================] - 0s 4ms/step - loss: 17.2897 - accuracy: 0.9981
# 97/97 [==============================] - 0s 4ms/step - loss: 16.9769 - accuracy: 0.9981
#  > Epoch 330
# 97/97 [==============================] - 0s 4ms/step - loss: 18.4543 - accuracy: 0.9976
# 97/97 [==============================] - 0s 4ms/step - loss: 18.3963 - accuracy: 0.9976
# 97/97 [==============================] - 0s 4ms/step - loss: 21.4843 - accuracy: 0.9965
# 97/97 [==============================] - 0s 4ms/step - loss: 15.8061 - accuracy: 0.9979
# 97/97 [==============================] - 0s 4ms/step - loss: 17.0598 - accuracy: 0.9979
# 97/97 [==============================] - 0s 4ms/step - loss: 19.9550 - accuracy: 0.9969
# 97/97 [==============================] - 0s 4ms/step - loss: 17.5647 - accuracy: 0.9974
# 97/97 [==============================] - 0s 4ms/step - loss: 19.9788 - accuracy: 0.9971
# 97/97 [==============================] - 0s 4ms/step - loss: 23.3691 - accuracy: 0.9958
# 97/97 [==============================] - 0s 4ms/step - loss: 20.0076 - accuracy: 0.9969
#  > Epoch 340
# 97/97 [==============================] - 0s 3ms/step - loss: 14.1583 - accuracy: 0.9991
# 97/97 [==============================] - 0s 3ms/step - loss: 16.1650 - accuracy: 0.9982
# 97/97 [==============================] - 0s 4ms/step - loss: 22.5750 - accuracy: 0.9961
# 97/97 [==============================] - 0s 3ms/step - loss: 21.5021 - accuracy: 0.9968
# 97/97 [==============================] - 0s 3ms/step - loss: 18.5820 - accuracy: 0.9972
# 97/97 [==============================] - 0s 4ms/step - loss: 13.8716 - accuracy: 0.9993
# 97/97 [==============================] - 0s 4ms/step - loss: 17.5794 - accuracy: 0.9978
# 97/97 [==============================] - 0s 4ms/step - loss: 20.1460 - accuracy: 0.9969
# 97/97 [==============================] - 0s 4ms/step - loss: 25.7328 - accuracy: 0.9951
# 97/97 [==============================] - 0s 4ms/step - loss: 18.4304 - accuracy: 0.9975
#  > Epoch 350
# 97/97 [==============================] - 0s 4ms/step - loss: 14.9741 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 14.0018 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 18.4063 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6940 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 18.2484 - accuracy: 0.9973
# 97/97 [==============================] - 0s 4ms/step - loss: 18.6151 - accuracy: 0.9973
# 97/97 [==============================] - 0s 4ms/step - loss: 16.6212 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 17.6116 - accuracy: 0.9979
# 97/97 [==============================] - 0s 4ms/step - loss: 18.1430 - accuracy: 0.9975
# 97/97 [==============================] - 0s 4ms/step - loss: 22.0988 - accuracy: 0.9958
#  > Epoch 360
# 97/97 [==============================] - 0s 3ms/step - loss: 14.0048 - accuracy: 0.9993
# 97/97 [==============================] - 0s 3ms/step - loss: 16.4874 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 16.7710 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 19.2287 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 18.6840 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 15.9717 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 19.0443 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 18.1280 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 18.9818 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 15.3459 - accuracy: 0.9985
#  > Epoch 370
# 97/97 [==============================] - 0s 3ms/step - loss: 16.2682 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 15.0007 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 19.4436 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 17.3434 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 13.0527 - accuracy: 0.9990
# 97/97 [==============================] - 0s 3ms/step - loss: 17.4052 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 20.1185 - accuracy: 0.9969
# 97/97 [==============================] - 0s 3ms/step - loss: 21.7508 - accuracy: 0.9961
# 97/97 [==============================] - 0s 3ms/step - loss: 16.5023 - accuracy: 0.9980
# 97/97 [==============================] - 0s 4ms/step - loss: 26.5714 - accuracy: 0.9945
#  > Epoch 380
# 97/97 [==============================] - 0s 3ms/step - loss: 17.6863 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 17.4878 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 19.5121 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 13.9562 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 20.9618 - accuracy: 0.9961
# 97/97 [==============================] - 0s 4ms/step - loss: 26.1195 - accuracy: 0.9946
# 97/97 [==============================] - 0s 4ms/step - loss: 20.7839 - accuracy: 0.9968
# 97/97 [==============================] - 0s 4ms/step - loss: 18.3290 - accuracy: 0.9974
# 97/97 [==============================] - 0s 4ms/step - loss: 14.2717 - accuracy: 0.9989
# 97/97 [==============================] - 0s 4ms/step - loss: 18.2872 - accuracy: 0.9974
#  > Epoch 390
# 97/97 [==============================] - 0s 4ms/step - loss: 16.6681 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 19.9552 - accuracy: 0.9966
# 97/97 [==============================] - 0s 3ms/step - loss: 19.1824 - accuracy: 0.9971
# 97/97 [==============================] - 0s 4ms/step - loss: 20.1012 - accuracy: 0.9971
# 97/97 [==============================] - 0s 4ms/step - loss: 13.9147 - accuracy: 0.9988
# 97/97 [==============================] - 0s 4ms/step - loss: 19.5764 - accuracy: 0.9968
# 97/97 [==============================] - 0s 3ms/step - loss: 20.2746 - accuracy: 0.9967
# 97/97 [==============================] - 0s 3ms/step - loss: 15.9253 - accuracy: 0.9983
# 97/97 [==============================] - 0s 4ms/step - loss: 15.5209 - accuracy: 0.9983
# 97/97 [==============================] - 0s 4ms/step - loss: 16.4276 - accuracy: 0.9983
#  > Epoch 400
# 97/97 [==============================] - 0s 4ms/step - loss: 16.6414 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 19.7234 - accuracy: 0.9971
# 97/97 [==============================] - 0s 3ms/step - loss: 15.0859 - accuracy: 0.9984
# 97/97 [==============================] - 0s 3ms/step - loss: 16.1517 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 16.5441 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 19.5516 - accuracy: 0.9971
# 97/97 [==============================] - 0s 3ms/step - loss: 18.7344 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 20.4298 - accuracy: 0.9966
# 97/97 [==============================] - 0s 3ms/step - loss: 16.9907 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 16.5287 - accuracy: 0.9979
#  > Epoch 410
# 97/97 [==============================] - 0s 3ms/step - loss: 13.2323 - accuracy: 0.9991
# 97/97 [==============================] - 0s 3ms/step - loss: 16.5178 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 18.6202 - accuracy: 0.9970
# 97/97 [==============================] - 0s 3ms/step - loss: 14.9426 - accuracy: 0.9986
# 97/97 [==============================] - 0s 4ms/step - loss: 19.8399 - accuracy: 0.9970
# 97/97 [==============================] - 0s 4ms/step - loss: 14.8957 - accuracy: 0.9987
# 97/97 [==============================] - 0s 4ms/step - loss: 17.0981 - accuracy: 0.9981
# 97/97 [==============================] - 0s 4ms/step - loss: 18.5843 - accuracy: 0.9973
# 97/97 [==============================] - 0s 4ms/step - loss: 20.0612 - accuracy: 0.9965
# 97/97 [==============================] - 0s 4ms/step - loss: 18.8118 - accuracy: 0.9972
#  > Epoch 420
# 97/97 [==============================] - 0s 3ms/step - loss: 17.2422 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 17.6525 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 22.1236 - accuracy: 0.9962
# 97/97 [==============================] - 0s 3ms/step - loss: 17.9578 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 18.3744 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 18.4445 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 16.2813 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 18.8400 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 15.3058 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6568 - accuracy: 0.9979
#  > Epoch 430
# 97/97 [==============================] - 0s 3ms/step - loss: 16.0234 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 22.5277 - accuracy: 0.9957
# 97/97 [==============================] - 0s 4ms/step - loss: 15.7289 - accuracy: 0.9982
# 97/97 [==============================] - 0s 4ms/step - loss: 25.1559 - accuracy: 0.9948
# 97/97 [==============================] - 0s 4ms/step - loss: 19.9156 - accuracy: 0.9968
# 97/97 [==============================] - 0s 4ms/step - loss: 17.2393 - accuracy: 0.9975
# 97/97 [==============================] - 0s 4ms/step - loss: 17.4707 - accuracy: 0.9980
# 97/97 [==============================] - 0s 4ms/step - loss: 14.7475 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 19.5194 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 22.4568 - accuracy: 0.9960
#  > Epoch 440
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5423 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 25.2428 - accuracy: 0.9948
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6412 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 14.8585 - accuracy: 0.9985
# 97/97 [==============================] - 0s 3ms/step - loss: 22.9411 - accuracy: 0.9962
# 97/97 [==============================] - 0s 3ms/step - loss: 12.7725 - accuracy: 0.9994
# 97/97 [==============================] - 0s 3ms/step - loss: 17.7667 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 17.4639 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 16.3955 - accuracy: 0.9979
# 97/97 [==============================] - 0s 3ms/step - loss: 19.6994 - accuracy: 0.9970
#  > Epoch 450
# 97/97 [==============================] - 0s 3ms/step - loss: 19.8942 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 13.5513 - accuracy: 0.9991
# 97/97 [==============================] - 0s 3ms/step - loss: 19.8908 - accuracy: 0.9971
# 97/97 [==============================] - 0s 3ms/step - loss: 18.3381 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 18.7216 - accuracy: 0.9972
# 97/97 [==============================] - 0s 3ms/step - loss: 17.7501 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6484 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 12.5376 - accuracy: 0.9994
# 97/97 [==============================] - 0s 3ms/step - loss: 17.8609 - accuracy: 0.9976
# 97/97 [==============================] - 0s 3ms/step - loss: 22.1819 - accuracy: 0.9961
#  > Epoch 460
# 97/97 [==============================] - 0s 3ms/step - loss: 20.8027 - accuracy: 0.9967
# 97/97 [==============================] - 0s 4ms/step - loss: 15.1491 - accuracy: 0.9985
# 97/97 [==============================] - 0s 4ms/step - loss: 12.8806 - accuracy: 0.9994
# 97/97 [==============================] - 0s 4ms/step - loss: 15.4725 - accuracy: 0.9984
# 97/97 [==============================] - 0s 4ms/step - loss: 15.2677 - accuracy: 0.9982
# 97/97 [==============================] - 0s 4ms/step - loss: 18.3247 - accuracy: 0.9971
# 97/97 [==============================] - 0s 4ms/step - loss: 17.7975 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 15.5176 - accuracy: 0.9982
# 97/97 [==============================] - 0s 3ms/step - loss: 24.4908 - accuracy: 0.9954
# 97/97 [==============================] - 0s 3ms/step - loss: 21.3096 - accuracy: 0.9964
#  > Epoch 470
# 97/97 [==============================] - 0s 3ms/step - loss: 20.2916 - accuracy: 0.9968
# 97/97 [==============================] - 0s 3ms/step - loss: 17.3942 - accuracy: 0.9978
# 97/97 [==============================] - 0s 3ms/step - loss: 16.6153 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 16.5595 - accuracy: 0.9980
# 97/97 [==============================] - 0s 3ms/step - loss: 18.7849 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 24.9687 - accuracy: 0.9949
# 97/97 [==============================] - 0s 3ms/step - loss: 12.6748 - accuracy: 0.9994
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5685 - accuracy: 0.9975
# 97/97 [==============================] - 0s 3ms/step - loss: 17.5657 - accuracy: 0.9974
# 97/97 [==============================] - 0s 3ms/step - loss: 17.9076 - accuracy: 0.9975
#  > Epoch 480
# 97/97 [==============================] - 0s 3ms/step - loss: 14.6893 - accuracy: 0.9987
# 97/97 [==============================] - 0s 3ms/step - loss: 21.2287 - accuracy: 0.9965
# 97/97 [==============================] - 0s 3ms/step - loss: 16.2923 - accuracy: 0.9981
# 97/97 [==============================] - 0s 3ms/step - loss: 20.9732 - accuracy: 0.9963
# 97/97 [==============================] - 0s 3ms/step - loss: 15.9882 - accuracy: 0.9983
# 97/97 [==============================] - 0s 3ms/step - loss: 16.9586 - accuracy: 0.9977
# 97/97 [==============================] - 0s 3ms/step - loss: 15.4785 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 25.3015 - accuracy: 0.9947
# 97/97 [==============================] - 0s 3ms/step - loss: 15.3296 - accuracy: 0.9986
# 97/97 [==============================] - 0s 3ms/step - loss: 15.0377 - accuracy: 0.9984
#  > Epoch 490
# 97/97 [==============================] - 0s 3ms/step - loss: 22.3328 - accuracy: 0.9957
# 97/97 [==============================] - 0s 3ms/step - loss: 13.0826 - accuracy: 0.9992
# 97/97 [==============================] - 0s 3ms/step - loss: 14.2597 - accuracy: 0.9988
# 97/97 [==============================] - 0s 3ms/step - loss: 14.2908 - accuracy: 0.9986
# 97/97 [==============================] - 0s 3ms/step - loss: 17.8591 - accuracy: 0.9973
# 97/97 [==============================] - 0s 3ms/step - loss: 15.2802 - accuracy: 0.9987
# 97/97 [==============================] - 0s 4ms/step - loss: 16.6216 - accuracy: 0.9979
# 97/97 [==============================] - 0s 4ms/step - loss: 16.3552 - accuracy: 0.9981
# 97/97 [==============================] - 0s 4ms/step - loss: 18.9758 - accuracy: 0.9974
# 97/97 [==============================] - 0s 4ms/step - loss: 19.3610 - accuracy: 0.9968
#  > Epoch 500
# 97/97 [==============================] - 0s 4ms/step - loss: 14.9837 - accuracy: 0.9987
# 1/1 [==============================] - 1s 1s/step - loss: 6.2192 - accuracy: 1.0000

# %%
model.save_weights("training")
model_rec.save_weights("training_REC")
model, model_rec = build_model(hidden_size, use_stateful=False)
model.load_weights("training")
model_rec.load_weights("training_REC")
model.summary()
# Out:
# Model: "model_92"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_47 (InputLayer)       [(1, None, 3)]            0
#
#  simple_rnn_46 (SimpleRNN)   (1, None, 10)             140
#
#  dense_46 (Dense)            (1, None, 2)              22
#
# =================================================================
# Total params: 162 (648.00 Byte)
# Trainable params: 162 (648.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Evaluación del modelo

# %%
print(" > Train dataset:")
model.evaluate(dataset_x_train_b1, dataset_y_train_b1, batch_size=1)
print(" > Big dataset:")
model.evaluate(dataset_x_big, dataset_y_big, batch_size=1)
print(" > Long dataset:")
model.evaluate(dataset_x_long, dataset_y_long, batch_size=1)
print(" > All as dataset:")
model.evaluate(dataset_x_allas, dataset_y_allas, batch_size=1)
print(" > All bs dataset:")
model.evaluate(dataset_x_allbs, dataset_y_allbs, batch_size=1)
# Out:
#  > Train dataset:
# 1/1 [==============================] - 3s 3s/step - loss: 6.2192 - accuracy: 1.0000
#  > Big dataset:
# 1/1 [==============================] - 6s 6s/step - loss: 12.4550 - accuracy: 1.0000
#  > Long dataset:
# 1/1 [==============================] - 1s 1s/step - loss: 2.5484 - accuracy: 1.0000
#  > All as dataset:
# 1/1 [==============================] - 1s 833ms/step - loss: 1.9831 - accuracy: 1.0000
#  > All bs dataset:
# 1/1 [==============================] - 1s 834ms/step - loss: 2.1322 - accuracy: 1.0000
# [2.13218092918396, 1.0]

# %% [markdown]
# ## Análisis y algoritmo DSP

# %%
hs = np.concatenate((model_rec.predict(dataset_x_train_b1, batch_size=1)))
ys = np.concatenate((dataset_y_train_b1))
print(hs.shape, ys.shape)
# Out:
# 1/1 [==============================] - 3s 3s/step
# (50001, 10) (50001,)

# %%
pca = PCA(n_components=2)
pca.fit(hs)
hs_2d = pca.transform(hs)

# %%
plt.grid()
plt.plot(hs_2d[:, 0], hs_2d[:, 1], '.', alpha=0.01, markersize=3)

plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.show()

# %%
# Visualización de activación de cada neurona oculta
plt.figure(figsize=(20,5))
plt.imshow(hs[:30].T, cmap="binary", vmin=-1, vmax=1)
plt.colorbar()
plt.xlabel("Tiempo")
plt.ylabel("# Neurona")
plt.yticks(range(10), range(10))
plt.show()

# %%
Wxh = model.layers[1].weights[0].numpy()
Whh = model.layers[1].weights[1].numpy()
Why = model.layers[2].weights[0].numpy()[:, 1][:, None]
bh = model.layers[1].weights[2].numpy()

# %%
vmax = np.abs(Wxh).max()
vmin = -vmax
plt.imshow(Wxh, vmin=vmin, vmax=vmax, cmap="bwr")
plt.colorbar()
plt.title("$\mathbf{W}^{x}$")
plt.ylabel("Input")
plt.xlabel("Output")
plt.grid(alpha=0.2)
plt.yticks(range(3), ["a", "b", "$"])
plt.xticks(range(10), range(10))
plt.show()

# %%
vmax = np.abs(Whh).max()
vmin = -vmax
plt.imshow(Whh, vmin=vmin, vmax=vmax, cmap="bwr")
plt.colorbar()
plt.title("$\mathbf{W}^{h}$")
plt.ylabel("Input")
plt.xlabel("Output")
plt.grid(alpha=0.2)
plt.xticks(range(10), range(10))
plt.yticks(range(10), range(10))
plt.show()

# %%
vmax = np.abs(Why).max()
vmin = -vmax
plt.imshow(Why, vmin=vmin, vmax=vmax, cmap="bwr")
plt.colorbar()
plt.title("$\mathbf{W}^{y}$")
plt.ylabel("Input")
plt.xlabel("Output")
plt.xticks([])
plt.yticks(range(10), range(10))
plt.show()

# %% [markdown]
# ### Paso 1: Clustering del espacio de estados interno

# %%
from sklearn.cluster import KMeans
K = 7
km = KMeans(K, n_init="auto")
km.fit(hs)
clusters = km.predict(hs)

# %%
plt.grid()
for c in np.unique(clusters):
    plt.plot(hs_2d[clusters==c, 0], hs_2d[clusters==c, 1], '.', alpha=1, markersize=3)
    
plt.title("RNN con "+str(hidden_size)+" neuronas")
    
plt.text(
    hs_2d[:, 0].max() * (0.4 if K==6 else 0.5),  # Coordenada x
    hs_2d[:, 1].max() * 0.9,  # Coordenada y
    "KMeans - K = "+str(K),  # Texto
    fontsize=12,  # Tamaño de la fuente
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5')  # Recuadro
)

plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.show()

# %% [markdown]
# ### Paso 2: Estracción de la tabla de transiciones

# %%
input_file = problema + "_train_x.txt"
text_x = open(input_file, 'r').read()

# %%
tabla_transiciones = {}
estado_aceptacion = {}
for i in tqdm(range(len(clusters))):
    simbolo = text_x[i]
    aceptar = ys[i]
    if i == 0:
        estado_ini = -1
    else:
        estado_ini = clusters[i-1]
    estado_aceptar = ys[i]
    estado_fin = clusters[i]
    if estado_fin in estado_aceptacion:
        if estado_aceptar in estado_aceptacion[estado_fin]:
            estado_aceptacion[estado_fin][estado_aceptar == 1] += 1
        else:
            estado_aceptacion[estado_fin][estado_aceptar == 1] = 1
    else:
        estado_aceptacion[estado_fin] = {estado_aceptar == 1: 1}
    if estado_ini in tabla_transiciones:
        if simbolo in tabla_transiciones[estado_ini]:
            if estado_fin in tabla_transiciones[estado_ini][simbolo]:
                tabla_transiciones[estado_ini][simbolo][estado_fin] += 1
            else:
                tabla_transiciones[estado_ini][simbolo][estado_fin] = 1
        else:
            tabla_transiciones[estado_ini][simbolo] = {estado_fin: 1}
    else:
        tabla_transiciones[estado_ini] = {simbolo: {estado_fin: 1}}
# Out:
# 100%|█████████████████████████████████| 50001/50001 [00:00<00:00, 374052.06it/s]

# %%
# Las transiciones pueden ser no deterministas, luego se gestionan llamando a la función
# to_deterministic

for estado_ini in tabla_transiciones:
    for simbolo in tabla_transiciones[estado_ini]:
        suma = sum(tabla_transiciones[estado_ini][simbolo].values())
        for estado_fin in tabla_transiciones[estado_ini][simbolo]:
            tabla_transiciones[estado_ini][simbolo][estado_fin] /= suma
tabla_transiciones
# Out:
# {-1: {'$': {0: 1.0}},
#  0: {'b': {0: 1.0}, 'a': {4: 1.0}, '$': {0: 1.0}},
#  4: {'b': {2: 1.0}, 'a': {1: 1.0}, '$': {6: 1.0}},
#  2: {'a': {1: 1.0}, 'b': {2: 1.0}, '$': {6: 1.0}},
#  1: {'a': {5: 1.0}, 'b': {3: 1.0}, '$': {3: 1.0}},
#  5: {'a': {1: 1.0}, 'b': {2: 1.0}, '$': {6: 1.0}},
#  3: {'b': {0: 1.0}, 'a': {4: 1.0}, '$': {0: 1.0}},
#  6: {'b': {0: 1.0}, 'a': {4: 1.0}, '$': {0: 1.0}}}

# %%
# Si en esta celda salen estados no deterministas en su salida, el autómata resultante
# fallará, ya que no se están considerando estados con salida probabilistica

for estado_ini in estado_aceptacion:
    suma = sum(estado_aceptacion[estado_ini].values())
    for estado_aceptar in estado_aceptacion[estado_ini]:
        estado_aceptacion[estado_ini][estado_aceptar] /= suma
estado_aceptacion
# Out:
# {0: {True: 1.0},
#  4: {False: 1.0},
#  2: {False: 1.0},
#  1: {True: 1.0},
#  5: {False: 1.0},
#  3: {True: 1.0},
#  6: {True: 1.0}}

# %%
# Se añade a las transiciones un estado sumidero para simplificar la tabla y tenerla
# completa
tabla_transiciones[-2] = {'$': {-1: 1.0}, "a": {-2: 1.0}, "b": {-2: 1.0}}

for simbolo in ["a", "b", "$"]:
    for estado_ini in tabla_transiciones:
        if simbolo not in tabla_transiciones[estado_ini]:
            tabla_transiciones[estado_ini][simbolo] = {-2: 1.0}
tabla_transiciones
# Out:
# {-1: {'$': {0: 1.0}, 'a': {-2: 1.0}, 'b': {-2: 1.0}},
#  0: {'b': {0: 1.0}, 'a': {4: 1.0}, '$': {0: 1.0}},
#  4: {'b': {2: 1.0}, 'a': {1: 1.0}, '$': {6: 1.0}},
#  2: {'a': {1: 1.0}, 'b': {2: 1.0}, '$': {6: 1.0}},
#  1: {'a': {5: 1.0}, 'b': {3: 1.0}, '$': {3: 1.0}},
#  5: {'a': {1: 1.0}, 'b': {2: 1.0}, '$': {6: 1.0}},
#  3: {'b': {0: 1.0}, 'a': {4: 1.0}, '$': {0: 1.0}},
#  6: {'b': {0: 1.0}, 'a': {4: 1.0}, '$': {0: 1.0}},
#  -2: {'$': {-1: 1.0}, 'a': {-2: 1.0}, 'b': {-2: 1.0}}}

# %%
for estado in tabla_transiciones:
    if estado not in estado_aceptacion:
        estado_aceptacion[estado] = {False: 1.0}
estado_aceptacion
# Out:
# {0: {True: 1.0},
#  4: {False: 1.0},
#  2: {False: 1.0},
#  1: {True: 1.0},
#  5: {False: 1.0},
#  3: {True: 1.0},
#  6: {True: 1.0},
#  -1: {False: 1.0},
#  -2: {False: 1.0}}

# %% [markdown]
# ### Paso 3: Construir el autómata

# %%
estados = list(tabla_transiciones.keys())
crear_diagrama_de_estados(estados, tabla_transiciones, estado_aceptacion, -1)

# %%
## Pasamos el autómata a determinista
(estado_ini, 
 estados_dfa,
 tabla_transiciones_dfa, 
 estado_aceptacion_dfa) = to_deterministic(tabla_transiciones, estado_aceptacion)

crear_diagrama_de_estados(estados_dfa, tabla_transiciones_dfa, estado_aceptacion_dfa, estado_ini)

# %% [markdown]
# ### Paso 4: Minimización del autómata

# %%
(nuevos_estados, 
 nueva_tabla_transiciones, 
 nuevo_estado_aceptacion, 
 nuevo_estado_ini,
 eq_classes) = minimize(estados_dfa, 
                        tabla_transiciones_dfa, 
                        estado_aceptacion_dfa, 
                        estado_ini=list(tabla_transiciones_dfa[estado_ini]['$'].keys())[0])

crear_diagrama_de_estados(nuevos_estados, 
                          nueva_tabla_transiciones, 
                          nuevo_estado_aceptacion, 
                          estado_inicial=nuevo_estado_ini,
                          draw_dollar=False)
